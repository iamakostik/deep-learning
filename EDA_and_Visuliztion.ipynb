# %%
import numpy as np
import pandas as pd
import datetime

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
price_df = pd.read_csv('prices-split-adjusted.csv', index_col = 'date', parse_dates=True)

# %%
price_df
# Out:
#            symbol        open       close         low        high     volume
# date
# 2016-01-05   WLTW  123.430000  125.839996  122.309998  126.250000  2163600.0
# 2016-01-06   WLTW  125.239998  119.980003  119.940002  125.540001  2386400.0
# 2016-01-07   WLTW  116.379997  114.949997  114.930000  119.739998  2489500.0
# 2016-01-08   WLTW  115.480003  116.620003  113.500000  117.440002  2006300.0
# 2016-01-11   WLTW  117.010002  114.970001  114.089996  117.330002  1408600.0
# ...           ...         ...         ...         ...         ...        ...
# 2016-12-30    ZBH  103.309998  103.199997  102.849998  103.930000   973800.0
# 2016-12-30   ZION   43.070000   43.040001   42.689999   43.310001  1938100.0
# 2016-12-30    ZTS   53.639999   53.529999   53.270000   53.740002  1701200.0
# 2016-12-30    AIV   44.730000   45.450001   44.410000   45.590000  1380900.0
# 2016-12-30    FTV   54.200001   53.630001   53.389999   54.480000   705100.0
#
# [851264 rows x 6 columns]

# %%
price_df.symbol.unique()
# Out:
# array(['WLTW', 'A', 'AAL', 'AAP', 'AAPL', 'ABC', 'ABT', 'ACN', 'ADBE',
#        'ADI', 'ADM', 'ADP', 'ADS', 'ADSK', 'AEE', 'AEP', 'AES', 'AET',
#        'AFL', 'AGN', 'AIG', 'AIZ', 'AJG', 'AKAM', 'ALB', 'ALK', 'ALL',
#        'ALXN', 'AMAT', 'AME', 'AMG', 'AMGN', 'AMP', 'AMT', 'AMZN', 'AN',
#        'ANTM', 'AON', 'APA', 'APC', 'APD', 'APH', 'ARNC', 'ATVI', 'AVB',
#        'AVGO', 'AVY', 'AWK', 'AXP', 'AYI', 'AZO', 'BA', 'BAC', 'BAX',
#        'BBBY', 'BBT', 'BBY', 'BCR', 'BDX', 'BEN', 'BHI', 'BIIB', 'BK',
#        'BLK', 'BLL', 'BMY', 'BSX', 'BWA', 'BXP', 'C', 'CA', 'CAG', 'CAH',
#        'CAT', 'CB', 'CBG', 'CBS', 'CCI', 'CCL', 'CELG', 'CERN', 'CF',
#        'CHD', 'CHK', 'CHRW', 'CI', 'CINF', 'CL', 'CLX', 'CMA', 'CMCSA',
#        'CME', 'CMG', 'CMI', 'CMS', 'CNC', 'CNP', 'COF', 'COG', 'COH',
#        'COL', 'COO', 'COP', 'COST', 'CPB', 'CRM', 'CSCO', 'CSX', 'CTAS',
#        'CTL', 'CTSH', 'CTXS', 'CVS', 'CVX', 'CXO', 'D', 'DAL', 'DD', 'DE',
# ...

# %%
print("No. of stockes :-",len(price_df.symbol.unique()))
# Out:
# No. of stockes :- 501

# %%
price_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 851264 entries, 2016-01-05 to 2016-12-30
# Data columns (total 6 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   symbol  851264 non-null  object
#  1   open    851264 non-null  float64
#  2   close   851264 non-null  float64
#  3   low     851264 non-null  float64
#  4   high    851264 non-null  float64
#  5   volume  851264 non-null  float64
# dtypes: float64(5), object(1)
# memory usage: 45.5+ MB

# %%
price_df.describe()
# Out:
#                 open          close            low           high  \
# count  851264.000000  851264.000000  851264.000000  851264.000000
# mean       64.993618      65.011913      64.336541      65.639748
# std        75.203893      75.201216      74.459518      75.906861
# min         1.660000       1.590000       1.500000       1.810000
# 25%        31.270000      31.292776      30.940001      31.620001
# 50%        48.459999      48.480000      47.970001      48.959999
# 75%        75.120003      75.139999      74.400002      75.849998
# max      1584.439941    1578.130005    1549.939941    1600.930054
#
#              volume
# count  8.512640e+05
# mean   5.415113e+06
# std    1.249468e+07
# min    0.000000e+00
# 25%    1.221500e+06
# 50%    2.476250e+06
# 75%    5.222500e+06
# max    8.596434e+08

# %% [markdown]
# There is no null values.

# %% [markdown]
# # Data Visulization

# %%
import plotly.express as px
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.set_style('darkgrid')
matplotlib.rcParams['font.size'] = 14
matplotlib.rcParams['figure.figsize'] = (15, 7)
matplotlib.rcParams['figure.facecolor'] = '#00000000'
# %matplotlib inline

# %%
price_df.symbol.max()
# Out:
# 'ZTS'

# %% [markdown]
# **Let's try to visualize and compare stocks of some tech giants like apple, amazon, google, meta**

# %%
goog = price_df.query("symbol == 'GOOG'")
apl = price_df.query("symbol == 'AAPL'")
amz = price_df.query("symbol == 'AMZN'")

# %%
goog['close'].plot(label = "Alphabet", figsize = (18, 9))
apl['close'].plot(label = 'Apple')
amz['close'].plot(label = 'Amazon')

plt.title('Stock Prices of Alphabet, Apple and Amazon')
plt.legend()

# %% [markdown]
# Price of apple's stock is lower then other two. But we are not interested in the absolute prices for these companies but wanted to understand how these stock fluctuate with time. We can also use plotly to draw candlestick charts to visulize opening, closing, high and low prices to stocks altogether.

# %%
import plotly.graph_objects as go

fig = go.Figure(data=[go.Candlestick(x=apl.index,
                open=apl['open'],
                high=apl['high'],
                low=apl['low'],
                close=apl['close'])])
fig.update_layout(
    title='Apple Stock Chart',
    yaxis_title='APL Stock',
)
# Out:
# <div>                            <div id="1983d65b-2d03-41f7-bf0a-340c38738e56" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1983d65b-2d03-41f7-bf0a-340c38738e56")) {                    Plotly.newPlot(                        "1983d65b-2d03-41f7-bf0a-340c38738e56",                        [{"close":[30.5728568571,30.6257132857,30.1385707143,30.0828571428,30.2828578571,30.0157147143,29.6742858571,30.0928574285,29.9185714285,29.4185714285,30.7199992857,30.2471428571,29.7242851428,28.25,29.0100002857,29.4200001428,29.6971435714,28.4699992857,27.4371432857,27.8185711428,27.9799995714,28.4614277143,27.4357147143,27.9228572857,27.7314281428,28.0271434285,27.8742867143,28.3814277143,28.6257132857,29.0571422857,28.9357147143,28.9899997143,28.8099994285,28.
# ...

# %%
goog['volume'].plot(label = "Alphabet", figsize = (18, 9))
apl['volume'].plot(label = 'Apple')
amz['volume'].plot(label = 'Amazon')

plt.title('Volume of stock traded')
plt.legend()

# %%
apl.iloc[apl['volume'].argmax()]
# Out:
# symbol           AAPL
# open        47.074287
# close       48.664288
# low          46.57143
# high        49.251427
# volume    470249500.0
# Name: 2011-01-18 00:00:00, dtype: object

# %%
apl.iloc[255:265].open.plot(figsize = (15, 7))
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# Volume of stock traded of apple is highest at 18 Jan 2011. Shares of Apple fell that day, one day after chief executive and co-founder Steve Jobs announced another leave of absence because of health problems. We can refer to this link for more detail
#
# https://money.cnn.com/2011/01/18/technology/apple_jobs/index.htm

# %% [markdown]
# Although price of apple's stock is lower but volume traded of apple's stocks is greater then other two. Now let's check total trading.

# %%
goog['TotalTraded'] = goog['open'] * goog['volume']
apl['TotalTraded']= apl['open'] * apl['volume']
amz['TotalTraded']= amz['open'] * amz['volume']

# %%
goog['TotalTraded'].plot(label = "Alphabet", figsize = (18, 9))
apl['TotalTraded'].plot(label = 'Apple')
amz['TotalTraded'].plot(label = 'Amazon')

plt.title('Total Traded Amount')
plt.legend()

# %%
goog.iloc[goog['TotalTraded'].argmax()]
# Out:
# symbol                       GOOG
# open                   486.467448
# close                  503.817423
# low                    485.182259
# high                   505.834882
# volume                 23219400.0
# TotalTraded    11295482263.855873
# Name: 2013-10-18 00:00:00, dtype: object

# %% [markdown]
# Volume of stock traded of apple is highest at 18 OCT 2013.
#
# https://www.theguardian.com/business/2013/oct/18/google-share-price-record-high

# %% [markdown]
# Only volume or stock prices do not provide a comparison between companies. In this case, we have plotted a graph for Volume * Share price to better compare the companies. As we can clearly see from the graph that Apple seems to be traded on a higher side.

# %% [markdown]
# Because stock markets are very volatile and prices changes rapidly. So to capture any trend we should smooth out data. So I will be taking 2 month and 4 month average.

# %%
def MovingAvg(df, cmp):
    df['MA2M'] = df['open'].rolling(60).mean()
    df['MA4M'] = df['open'].rolling(120).mean()
    df['close'].plot(figsize = (18,9))
    df['MA2M'].plot()
    df['MA4M'].plot()
    plt.title('Moving avg of '+cmp+' stocks')
    plt.legend()

# %%
MovingAvg(goog, 'Alphabet')

# %%
MovingAvg(apl, 'Apple')

# %%
MovingAvg(amz, 'Amazon')

# %% [markdown]
# Because all three are IT companies. So maybe there is some relation b/w stocks of these companies. Let's see if there is some correlation b/w these three stocks.

# %%
tech_gnt = pd.concat([goog['open'], apl['open'], amz['open']], axis=1)
tech_gnt.columns = ['Alphabet Open', 'Apple Open', 'Amazon Open']

# %%
g = sns.pairplot(tech_gnt, diag_kws = {'bins':40}, plot_kws = {'s':15})
g.fig.set_size_inches(12,9)

# %% [markdown]
# As we can see from the plot above that there is somewhat positive linear correlation between opening stocks prizes of alphabet and amazon.

# %% [markdown]
# ## Daily Percentage Gain
#
# $$r_t = {p_t \over p_{t-1}}-1$$

# %%
goog['returns'] = (goog['close']/goog['close'].shift(1))-1
apl['returns'] = (apl['close']/apl['close'].shift(1))-1
amz['returns'] = (amz['close']/amz['close'].shift(1))-1

# %%
plt.hist(goog['returns'], alpha=0.5, label='Alphabet Stocks Returns', bins=50, color='b')
plt.hist(apl['returns'], alpha=0.5, label='Apple Stocks Returns', bins=50, color='r')
plt.hist(amz['returns'], alpha=0.5, label='Amazon Stocks Returns', bins=50, color='g')
plt.legend()
matplotlib.rcParams['figure.figsize'] = (12, 9)

# %%
goog['returns'].plot(kind='kde',label='Alphabet Stocks Returns', color='b')
apl['returns'].plot(kind='kde', label='Apple Stocks Returns', color='r')
amz['returns'].plot(kind='kde',label='Amazon Stocks Returns', color='g')
plt.legend()

# %% [markdown]
# So looking at the plots we can say that stocks of alphabet are a little less volatile then other two. Although all three are similar in term of stability

# %%
gnt_returns = pd.concat([goog['returns'], apl['returns'], amz['returns']], axis=1)
gnt_returns.columns = ['Alphabet Returns', 'Apple Returns', 'Amazon Returns']

sns.boxplot(data=gnt_returns)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(gnt_returns)

# %% [markdown]
# PairPlot b/w returns also shows there is some kind of relation b/w amazon and alphabet stocks.

# %% [markdown]
# ## Cumulative Return
#
# $$i_t = (1+r_t)i_{t-1}$$

# %%
goog['Cumulative Return'] = (1+goog['returns']).cumprod()-1
apl['Cumulative Return'] = (1+apl['returns']).cumprod()-1
amz['Cumulative Return'] = (1+amz['returns']).cumprod()-1

# %%
goog['Cumulative Return'].plot(label = "Alphabet", figsize = (18, 9))
apl['Cumulative Return'].plot(label = 'Apple')
amz['Cumulative Return'].plot(label = 'Amazon')
plt.legend()

# %% [markdown]
# Cumulative returns os alphabet is lower than the other two. Most of the times return of apple's stocks are highest. But in recent time returns on amazon's stcoks have drastically increased.
